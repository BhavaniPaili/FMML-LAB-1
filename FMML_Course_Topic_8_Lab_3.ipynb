# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavaniPaili/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 13:11:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   277MB/s    in 0.2s
#
# 2024-03-30 13:11:21 (277 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3773    1401.1489v1  To answer the existence of optimal swimmer lea...  stat
# 21045  1707.01415v1  We formulate a strong equivalence between mach...    cs
# 21528   0908.2579v2  Section 1.3 was incorrect, and 2.1 will be rem...  stat
# 35536   0811.0971v1  We have used Galois lattices for mining hydrob...    cs
# 12212  1710.06766v1  In this paper, we study the pooled data proble...  stat
# ...             ...                                                ...   ...
# 6199   1609.03772v1  We formulate and analyze a graphical model sel...  stat
# 12593  1803.03880v1  It is by now well-known that small adversarial...  stat
# 36191   1303.7085v1  Management of security policies has become inc...    cs
# 12442  1802.01751v2  We construct near-optimal coresets for kernel ...    cs
# 29213  1708.07601v2  In this paper, we propose a vector total varia...    cs
#
#                                                    title  year  \
# 3773   Key point selection and clustering of swimmer ...  2014
# 21045  Machine Learning, Deepest Learning: Statistica...  2017
# 21528      Convex Multiview Fisher Discriminant Analysis  2009
# 35536  Mining Complex Hydrobiological Data with Galoi...  2008
# 12212       Phase Transitions in the Pooled Data Problem  2017
# ...                                                  ...   ...
# 6199   Learning conditional independence structure fo...  2016
# 12593  Combating Adversarial Attacks Using Sparse Rep...  2018
# 36191  Semantic Matching of Security Policies to Supp...  2013
# 12442  Near-Optimal Coresets of Kernel Density Estimates  2018
# 29213  A wavelet frame coefficient total variational ...  2017
#
#                                                 keywords
# 3773   [existence, learningteaching, strategies, intr...
# 21045  [formulate, equivalence, artificial, intellige...
# 21528  [incorrect, submissions, rewritten, multiview,...
# 35536  [hydrobiological, macrophytes, macroscopic, ch...
# 12212  [identifying, associated, collection, revealin...
# ...                                                  ...
# 6199   [formulate, graphical, selection, inferring, c...
# 12593  [adversarial, perturbations, classification, r...
# 36191  [management, increasingly, difficult, consider...
# 12442  [construct, specifically, polynomial, construc...
# 29213  [variation, restoration, different, smoothing,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3773     [existence, learningteaching, strategies, intr...
# 21045    [formulate, equivalence, artificial, intellige...
# 21528    [incorrect, submissions, rewritten, multiview,...
# 35536    [hydrobiological, macrophytes, macroscopic, ch...
# 12212    [identifying, associated, collection, revealin...
#                                ...
# 3825     [answering, effective, automated, available, q...
# 25224    [automatic, segmentation, important, challengi...
# 21562    [correspondence, different, unsupervised, summ...
# 29551    [ethnicity, demographic, attribute, automatic,...
# 10546    [inference, observations, structure, generatin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8859 words.
# Out of those 4597 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="629d5d70-b227-490d-a42d-aa9665e44e16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("629d5d70-b227-490d-a42d-aa9665e44e16")) {                    Plotly.newPlot(                        "629d5d70-b227-490d-a42d-aa9665e44e16",                        [{"x":["framework","strategies","coordination","knowledge","performed","correlated","selection","existence","unsupervised","clustering","introduces","efficiently","correspondence","addressed","analogous","presented","statistical","discussion","discussed","lagrangian","propagation","formulation","intelligence","continuous","biological","equivalence","respected","candidate","implementation","resolution","canonical","assimilation","functions","rationale","calculations","structure","differential","hamiltonian","variational","formulate","providing","artificial","rewritten","multiview","discriminant","incorrect","submissions","characterized","modalities","efficient","approaches","according","relations","macroscopic","transform","approximate","variation","identifying","collection","asymptotic","transition","noiseless","revealing","associated","theoretic","information","transitions","increases","considerably","threshold","difficult","demonstrate","characterizing","interpolation","dimensional","extension","consisting","experimental","minimizes","important","parameters","especially","preserving","different","available","potential","generalizations","procedure","smoothness","objective","unlabeled","generalization","estimated","algorithm","enhancing","regularization","supervised","applications","nonlinear","embeddings","initially","classification","manifolds","dependent","progressive","algorithms","separation","embedding","direction","statisticians","imputation","generalized","combining","causality","estimating","incomplete","statistician","observational","judiciously","unfamiliar","challenging","beginning","demonstrated","estimation","enforcing","autoencoding","receptive","suggested","restricted","boltzmann","established","constraints","development","investigate","investigated","considerable","technique","unfortunately","coarsening","parallelizing","originally","attracted","applicable","refinement","producing","addresses","processing","multilevel","developed","introducing","differences","partitioning","resulting","partition","performance","evolutionary","competing","introduce","comparisons","considers","unequally","optimizing","contributions","operations","permutation","permutations","comparison","depending","considering","systematically","invariant","accuracies","extensive","comparable","typically","experiments","computing","approximating","literature","consistent","substantially","empirically","similarity","competitor","effective","identification","tremendous","effectively","leveraging","dirichlet","evaluation","researchers","practitioners","normalized","analytics","modelling","summarize","allocation","coherence","understand"],"y":[558,101,13,380,123,28,161,33,148,145,77,148,23,43,9,191,166,21,49,11,65,88,93,104,47,26,4,49,149,95,24,1,200,5,12,342,26,3,54,54,74,132,0,4,12,6,6,33,32,425,441,106,93,7,64,109,58,75,72,21,26,2,7,104,45,661,8,42,22,26,132,552,16,18,158,71,36,373,21,353,240,120,46,753,314,165,12,117,18,138,32,120,58,809,22,85,186,428,43,75,19,507,15,71,6,582,29,101,47,0,1,87,101,8,57,35,0,10,1,1,275,2,86,173,11,0,16,25,46,14,50,128,127,137,56,49,251,27,2,1,19,24,49,30,26,58,289,7,200,58,58,14,152,29,836,61,20,331,29,30,0,46,41,64,13,8,144,27,76,18,62,22,182,74,104,575,151,20,127,64,30,68,158,1,251,112,15,117,50,20,260,78,23,20,11,45,19,34,18,63],"type":"bar"},{"x":["framework","strategies","coordination","knowledge","performed","correlated","selection","existence","unsuperv ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4597,), (4597, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>We</span> <span style=''>Can</span> <span style=''>See</span> <span style=''>You</span> <span style=''>via</span> <span style=''>Wi</span> <span style=''>Fi</span> <span style=''>WiFi</span> <span style=''>Action</span> <span style='background-color:rgba(0, 255, 0, 0.6280087527352297);'>Recognition</span> <span style=''>via</span> <span style=''>Vision</span> <span style=''>based</span> <span style=''>Methods</span> <br/><br/><span style=''>Recently</span> <span style=''>Wi</span> <span style=''>Fi</span> <span style=''>has</span> <span style=''>caught</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>tremendous</span> <span style='background-color:rgba(0, 255, 0, 0.43209876543209874);'>attention</span> <span style=''>for</span> <span style=''>its</span> <span style=''>ubiquity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>Wi</span> <span style=''>Fis</span> <span style=''>low</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>privacy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preservation</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054054);'>researchers</span> <span style=''>have</span> <span style=''>been</span> <span style=''>putting</span> <span style=''>lots</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigation</span> <span style=''>into</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>on</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.6280087527352297);'>recognition</span> <span style=''>and</span> <span style=''>even</span> <span style=''>person</span> <span style='background-color:rgba(0, 255, 0, 0.3658536585365853);'>identification</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>offer</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>comprehensive</span> <span style=''>overview</span> <span style=''>on</span> <span style=''>these</span> <span style=''>two</span> <span style=''>topics</span> <span style=''>in</span> <span style=''>Wi</span> <span style=''>Fi</span> <span style=''>Also</span> <span style=''>through</span> <span style=''>looking</span> <span style=''>at</span> <span style=''>these</span> <span style=''>two</span> <span style=''>topics</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>unprecedented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>we</span> <span style=''>could</span> <span style=''>achieve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generality</span> <span style=''>instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>designing</span> <span style=''>specific</span> <span style=''>ad</span> <span style=''>hoc</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>scenario</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observing</span> <span style=''>the</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resemblance</span> <span style=''>of</span> <span style=''>Channel</span> <span style=''>State</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style=''>(CSI</span> <span style=''>a</span> <span style=''>fine</span> <span style=''>grained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>captured</span> <span style=''>from</span> <span style=''>the</span> <span style=''>received</span> <span style=''>Wi</span> <span style=''>Fi</span> <span style=''>signal)</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Causal</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>rules</span> <span style=''>for</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regimes</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regimes</span> <span style=''>is</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style=''>interest</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>medicine</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>method</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regime</span> <span style=''>The</span> <span style=''>method</span> <span style=''>roots</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>the</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>effects</span> <span style=''>within</span> <span style=''>the</span> <span style=''>nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighborhood</span> <span style=''>Although</span> <span style=''>the</span> <span style=''>method</span> <span style=''>is</span> <span style=''>simple</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possesses</span> <span style=''>nice</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>regime</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>That</span> <span style=''>is</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>regime</span> <span style=''>will</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eventually</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regime</span> <span style=''>as</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>However</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>reg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>megaman</span> <span style=''>Manifold</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Millions</span> <span style=''>of</span> <span style=''>points</span> <br/><br/><span style=''>Manifold</span> <span style=''>Learning</span> <span style=''>is</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>seeking</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.40934579439252344);'>dimensional</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3661417322834646);'>representation</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.40934579439252344);'>dimensional</span> <span style=''>data</span> <span style=''>Thus</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>at</span> <span style=''>least</span> <span style=''>in</span> <span style=''>theory</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.40934579439252344);'>dimensional</span> <span style=''>data</span> <span style=''>and</span> <span style=''>sample</span> <span style=''>sizes</span> <span style=''>to</span> <span style=''>enable</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.34593572778827975);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>Despite</span> <span style=''>this</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementations</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>scalable</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>Python</span> <span style=''>package</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implements</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>a</span> <span style=''>modular</span> <span style=''>and</span> <span style=''>scalable</span> <span style=''>fashion</span> <span style=''>using</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighbors</span> <span style=''>searches</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigendecompositions</span> <span style=''>The</span> <span style=''>package</span> <span style='background-color:rgba(0, 255, 0, 0.32307692307692304);'>incorporates</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>theoretical</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>unbiased</span> <span style='background-color:rgba(255, 0, 0, 0.37142857142857144);'>Laplacian</span> <span style='background-color:rgba(255, 0, 0, 0.6645962732919255);'>estimator</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.345935 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style=''>Mean</span> <span style=''>Metric</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>metric</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>from</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>it</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>Indeed</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>even</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>This</span> <span style=''>solution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possesses</span> <span style=''>several</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attractive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>(i)</span> <span style=''>an</span> <span style=''>innate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>appeal</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>(ii)</span> <span style=''>ease</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style=''>(iii)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>speed</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>LMNN</span> <span style=''>and</span> <span style=''>ITML</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>on</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>our</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistently</span> <span style=''>attains</span> <span style=''>higher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.0803024846957148)
# 	representation (0.12495498739647101)
# 	processing (0.10406913935902053)
# 	segmentation (0.07093986316168527)
# 	information (0.23802664746128915)
# 	knowledge (0.13683831472812388)
# 	detection (0.1310767014764134)
# 	different (0.2711559236586244)
# 	convolutional (0.13719841555635579)
# 	recognition (0.13395750810226864)
#
# Some Statistics words are:
# 	distributions (0.11319822046465645)
# 	statistical (0.15620365793376173)
# 	distribution (0.17745921898171033)
# 	algorithm (0.39100346020761245)
# 	theoretical (0.15818091942659418)
# 	variables (0.14285714285714285)
# 	estimation (0.175976272862086)
# 	inference (0.19525457241720218)
# 	dimensional (0.18635689569945627)
# 	regression (0.18487394957983194)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d0761c2c-886a-46ac-84cd-c22cf1a440d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0761c2c-886a-46ac-84cd-c22cf1a440d0")) {                    Plotly.newPlot(                        "d0761c2c-886a-46ac-84cd-c22cf1a440d0",                        [{"x":["framework","strategies","coordination","knowledge","performed","correlated","selection","existence","unsupervised","clustering","introduces","efficiently","correspondence","addressed","analogous","presented","statistical","discussion","discussed","lagrangian","propagation","formulation","intelligence","continuous","biological","equivalence","respected","candidate","implementation","resolution","canonical","assimilation","functions","rationale","calculations","structure","differential","hamiltonian","variational","formulate","providing","artificial","rewritten","multiview","discriminant","incorrect","submissions","characterized","modalities","efficient","approaches","according","relations","macroscopic","transform","approximate","variation","identifying","collection","asymptotic","transition","noiseless","revealing","associated","theoretic","information","transitions","increases","considerably","threshold","difficult","demonstrate","characterizing","interpolation","dimensional","extension","consisting","experimental","minimizes","important","parameters","especially","preserving","different","available","potential","generalizations","procedure","smoothness","objective","unlabeled","generalization","estimated","algorithm","enhancing","regularization","supervised","applications","nonlinear","embeddings","initially","classification","manifolds","dependent","progressive","algorithms","separation","embedding","direction","statisticians","imputation","generalized","combining","causality","estimating","incomplete","statistician","observational","judiciously","unfamiliar","challenging","beginning","demonstrated","estimation","enforcing","autoencoding","receptive","suggested","restricted","boltzmann","established","constraints","development","investigate","investigated","considerable","technique","unfortunately","coarsening","parallelizing","originally","attracted","applicable","refinement","producing","addresses","processing","multilevel","developed","introducing","differences","partitioning","resulting","partition","performance","evolutionary","competing","introduce","comparisons","considers","unequally","optimizing","contributions","operations","permutation","permutations","comparison","depending","considering","systematically","invariant","accuracies","extensive","comparable","typically","experiments","computing","approximating","literature","consistent","substantially","empirically","similarity","competitor","effective","identification","tremendous","effectively","leveraging","dirichlet","evaluation","researchers","practitioners","normalized","analytics","modelling","summarize","allocation","coherence","understand","comprehension","conditional","probabilistic","elimination","factorization","treewidth","interventional","represented","exponential","densities","recursive","distribution","probability","inference","factorized","representation","graphical","advantage","generalizes","distributions","approximation","extremely","expressive","successful","scalability","evaluated","robustness","effectiveness","correlations","benchmark","recurrent","limitation","processes","deterministic","stochastic","modelisation","mathematical","languages","semantics","mathematics","initiated","agricultural","portfolio","combinatorial","illustrate","uncertainty","programming","variables","constraint","diversification","management","conventional","implemented","involving","recognition","background", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	rewritten
# 	statisticians
# 	statistician
# 	autoencoding
# 	unequally
# 	warranted
# 	elucidates
# 	semiparametric
# 	collapsed
# 	conformal
# 	stabilized
# 	downweighting
# 	memberships
# 	supermodular
# 	visualisation
# 	standpoint
# 	curvatures
# 	embarrassingly
# 	reassignment
# 	covariates
# Some words which never appear in Statistics papers:
# 	respected
# 	coarsening
# 	modelisation
# 	initiated
# 	diversification
# 	milliseconds
# 	linguistically
# 	ontologies
# 	ignorance
# 	committing
# 	complementation
# 	inheritance
# 	microscope
# 	referenced
# 	grounding
# 	reformulated
# 	empowered
# 	algorithmically
# 	countering
# 	transmitted

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.089566533815306e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
